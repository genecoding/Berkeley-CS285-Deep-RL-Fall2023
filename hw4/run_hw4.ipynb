# %% [markdown]
# # Setup

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Problem 1

# %% [markdown]
# <u>What you will implement:</u>
# Collect a large dataset by executing random actions. Train a neural network dynamics model on this fixed dataset. The implementation that you will do here will be for training the dynamics model.
# * For the first command, the loss should go below 0.2 by iteration 500.

# %%
# default
# %run cs285/scripts/run_hw4.py -cfg experiments/mpc/halfcheetah_0_iter.yaml \
    --dir_name problem1
# Out:
# C:\Users\user\miniconda3\envs\cs285\lib\site-packages\gym\envs\registration.py:542: UserWarning: WARN: Overriding environment cheetah-cs285-v0
#   logger.warn(f"Overriding environment {spec.id}")
# C:\Users\user\miniconda3\envs\cs285\lib\site-packages\gym\envs\registration.py:542: UserWarning: WARN: Overriding environment obstacles-cs285-v0
#   logger.warn(f"Overriding environment {spec.id}")
# C:\Users\user\miniconda3\envs\cs285\lib\site-packages\gym\envs\registration.py:542: UserWarning: WARN: Overriding environment reacher-cs285-v0
#   logger.warn(f"Overriding environment {spec.id}")
# Namespace(config_file='experiments/mpc/halfcheetah_0_iter.yaml', sac_config_file=None, eval_interval=5000, num_render_trajectories=0, seed=1, no_gpu=False, which_gpu=0, dir_name='problem1', exp_name='')
# ...

# %% [markdown]
# Modify experiments/mpc/halfcheetah_0_iter.yaml to change some hyperparameters. Try at least two other configurations of hyperparameters that affect dynamics model training (e.g., number of layers, hidden size, or learning rate).

# %%
# set learning_rate=0.01 in halfcheetah_0_iter.yaml
# %run cs285/scripts/run_hw4.py -cfg experiments/mpc/halfcheetah_0_iter.yaml \
    --dir_name problem1 --exp_name cheetah_0iter_lr=0.01
# Out:
# Namespace(config_file='experiments/mpc/halfcheetah_0_iter.yaml', sac_config_file=None, eval_interval=5000, num_render_trajectories=0, seed=1, no_gpu=False, which_gpu=0, dir_name='problem1', exp_name='cheetah_0iter_lr=0.01')
# {'exp_name': 'cheetah_0iter_lr=0.01', 'ensemble_size': 3, 'mpc_horizon': 10, 'mpc_strategy': 'random', 'mpc_num_action_sequences': 1000, 'cem_num_iters': None, 'cem_num_elites': None, 'cem_alpha': None, 'initial_batch_size': 20000, 'batch_size': 8000, 'train_batch_size': 512, 'num_iters': 1, 'replay_buffer_capacity': 1000000, 'num_agent_train_steps_per_iter': 500, 'num_eval_trajectories': 0, 'ep_len': 500, 'log_string': 'cheetah-cs285-v0_cheetah_0iter_lr=0.01', 'env_name': 'cheetah-cs285-v0', 'hidden_size': 32, 'learning_rate': 0.01, 'num_layers': 1}
# ########################
# logging outputs to  C:\Users\user\Colab\Berkeley_DeepRL_Fall2023\hw4\cs285\scripts\../../data\problem1\cheetah-cs285-v0_cheetah_0iter_lr=0.01
# ########################
# Using CPU.
#
#
# ...

# %%
# set num_layers=3 in halfcheetah_0_iter.yaml
# %run cs285/scripts/run_hw4.py -cfg experiments/mpc/halfcheetah_0_iter.yaml \
    --dir_name problem1 --exp_name cheetah_0iter_numlayers=3
# Out:
# Namespace(config_file='experiments/mpc/halfcheetah_0_iter.yaml', sac_config_file=None, eval_interval=5000, num_render_trajectories=0, seed=1, no_gpu=False, which_gpu=0, dir_name='problem1', exp_name='cheetah_0iter_numlayers=3')
# {'exp_name': 'cheetah_0iter_numlayers=3', 'ensemble_size': 3, 'mpc_horizon': 10, 'mpc_strategy': 'random', 'mpc_num_action_sequences': 1000, 'cem_num_iters': None, 'cem_num_elites': None, 'cem_alpha': None, 'initial_batch_size': 20000, 'batch_size': 8000, 'train_batch_size': 512, 'num_iters': 1, 'replay_buffer_capacity': 1000000, 'num_agent_train_steps_per_iter': 500, 'num_eval_trajectories': 0, 'ep_len': 500, 'log_string': 'cheetah-cs285-v0_cheetah_0iter_numlayers=3', 'env_name': 'cheetah-cs285-v0', 'hidden_size': 32, 'learning_rate': 0.001, 'num_layers': 3}
# ########################
# logging outputs to  C:\Users\user\Colab\Berkeley_DeepRL_Fall2023\hw4\cs285\scripts\../../data\problem1\cheetah-cs285-v0_cheetah_0iter_numlayers=3
# ########################
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir data/problem1

# %% [markdown]
# # Problem 2

# %% [markdown]
# <u>What will you implement:</u>
# Action selection using your learned dynamics model and a given reward function.
# * Look at eval_return, which should be greater than -70 after one iteration.

# %%
# %run cs285/scripts/run_hw4.py -cfg experiments/mpc/obstacles_1_iter.yaml \
    --dir_name problem2
# Out:
# Namespace(config_file='experiments/mpc/obstacles_1_iter.yaml', sac_config_file=None, eval_interval=5000, num_render_trajectories=0, seed=1, no_gpu=False, which_gpu=0, dir_name='problem2', exp_name='')
# {'exp_name': 'obstacles_single', 'ensemble_size': 3, 'mpc_horizon': 10, 'mpc_strategy': 'random', 'mpc_num_action_sequences': 1000, 'cem_num_iters': None, 'cem_num_elites': None, 'cem_alpha': None, 'initial_batch_size': 5000, 'batch_size': 8000, 'train_batch_size': 512, 'num_iters': 1, 'replay_buffer_capacity': 1000000, 'num_agent_train_steps_per_iter': 20, 'num_eval_trajectories': 20, 'ep_len': 100, 'log_string': 'obstacles-cs285-v0_obstacles_single', 'env_name': 'obstacles-cs285-v0', 'hidden_size': 250, 'learning_rate': 0.001, 'num_layers': 2}
# ########################
# logging outputs to  C:\Users\user\Colab\Berkeley_DeepRL_Fall2023\hw4\cs285\scripts\../../data\problem2\obstacles-cs285-v0_obstacles_single
# ########################
# Using CPU.
#
#
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir data/problem2

# %% [markdown]
# # Problem 3

# %% [markdown]
# <u>What will you implement:</u>
# MBRL algorithm with on-policy data collection and iterative model training.
# * You should expect rewards of around -25 to -20 for the obstacles env, rewards of around -300 to -250 for the reacher env, and rewards of around 250-350 for the cheetah env.

# %%
# %run cs285/scripts/run_hw4.py -cfg experiments/mpc/obstacles_multi_iter.yaml \
    --dir_name problem3 -nvid 2
# Out:
# Namespace(config_file='experiments/mpc/obstacles_multi_iter.yaml', sac_config_file=None, eval_interval=5000, num_render_trajectories=2, seed=1, no_gpu=False, which_gpu=0, dir_name='problem3', exp_name='')
# {'exp_name': 'obstacles_multi', 'ensemble_size': 3, 'mpc_horizon': 10, 'mpc_strategy': 'random', 'mpc_num_action_sequences': 1000, 'cem_num_iters': None, 'cem_num_elites': None, 'cem_alpha': None, 'initial_batch_size': 5000, 'batch_size': 1000, 'train_batch_size': 512, 'num_iters': 12, 'replay_buffer_capacity': 1000000, 'num_agent_train_steps_per_iter': 20, 'num_eval_trajectories': 20, 'ep_len': 100, 'log_string': 'obstacles-cs285-v0_obstacles_multi', 'env_name': 'obstacles-cs285-v0', 'hidden_size': 250, 'learning_rate': 0.001, 'num_layers': 2}
# ########################
# logging outputs to  C:\Users\user\Colab\Berkeley_DeepRL_Fall2023\hw4\cs285\scripts\../../data\problem3\obstacles-cs285-v0_obstacles_multi
# ########################
# Using CPU.
#
#
# ...

# %%
# %run cs285/scripts/run_hw4.py -cfg experiments/mpc/reacher_multi_iter.yaml \
    --dir_name problem3 -nvid 2
# Out:
# Namespace(config_file='experiments/mpc/reacher_multi_iter.yaml', sac_config_file=None, eval_interval=5000, num_render_trajectories=2, seed=1, no_gpu=False, which_gpu=0, dir_name='problem3', exp_name='')
# {'exp_name': 'reacher_multi', 'ensemble_size': 3, 'mpc_horizon': 10, 'mpc_strategy': 'random', 'mpc_num_action_sequences': 1000, 'cem_num_iters': None, 'cem_num_elites': None, 'cem_alpha': None, 'initial_batch_size': 5000, 'batch_size': 5000, 'train_batch_size': 512, 'num_iters': 15, 'replay_buffer_capacity': 1000000, 'num_agent_train_steps_per_iter': 1000, 'num_eval_trajectories': 10, 'ep_len': 200, 'log_string': 'reacher-cs285-v0_reacher_multi', 'env_name': 'reacher-cs285-v0', 'hidden_size': 250, 'learning_rate': 0.001, 'num_layers': 2}
# ########################
# logging outputs to  C:\Users\user\Colab\Berkeley_DeepRL_Fall2023\hw4\cs285\scripts\../../data\problem3\reacher-cs285-v0_reacher_multi
# ########################
# Using CPU.
#
#
# ********** Iteration 1 ************
# ...

# %%
# %run cs285/scripts/run_hw4.py -cfg experiments/mpc/halfcheetah_multi_iter.yaml \
    --dir_name problem3 -nvid 2
# Out:
# Namespace(config_file='experiments/mpc/halfcheetah_multi_iter.yaml', sac_config_file=None, eval_interval=5000, num_render_trajectories=2, seed=1, no_gpu=False, which_gpu=0, dir_name='problem3', exp_name='')
# {'exp_name': 'cheetah_multi', 'ensemble_size': 3, 'mpc_horizon': 15, 'mpc_strategy': 'random', 'mpc_num_action_sequences': 1000, 'cem_num_iters': None, 'cem_num_elites': None, 'cem_alpha': None, 'initial_batch_size': 5000, 'batch_size': 5000, 'train_batch_size': 512, 'num_iters': 15, 'replay_buffer_capacity': 1000000, 'num_agent_train_steps_per_iter': 1500, 'num_eval_trajectories': 10, 'ep_len': 500, 'log_string': 'cheetah-cs285-v0_cheetah_multi', 'env_name': 'cheetah-cs285-v0', 'hidden_size': 250, 'learning_rate': 0.001, 'num_layers': 2}
# ########################
# logging outputs to  C:\Users\user\Colab\Berkeley_DeepRL_Fall2023\hw4\cs285\scripts\../../data\problem3\cheetah-cs285-v0_cheetah_multi
# ########################
# Using CPU.
#
#
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir data/problem3

# %% [markdown]
# # Problem 4

# %% [markdown]
# <u>What will you implement:</u>
# You will compare the performance of your MBRL algorithm as a function of three hyperparameters: the number of models in your ensemble, the number of random action sequences considered during each action selection, and the MPC planning horizon.

# %%
# default
# %run cs285/scripts/run_hw4.py -cfg experiments/mpc/reacher_ablation.yaml \
    --dir_name problem4
# Out:
# Namespace(config_file='experiments/mpc/reacher_ablation.yaml', sac_config_file=None, eval_interval=5000, num_render_trajectories=0, seed=1, no_gpu=False, which_gpu=0, dir_name='problem4', exp_name='')
# {'exp_name': 'reacher_ablation', 'ensemble_size': 3, 'mpc_horizon': 10, 'mpc_strategy': 'random', 'mpc_num_action_sequences': 1000, 'cem_num_iters': None, 'cem_num_elites': None, 'cem_alpha': None, 'initial_batch_size': 5000, 'batch_size': 800, 'train_batch_size': 512, 'num_iters': 15, 'replay_buffer_capacity': 1000000, 'num_agent_train_steps_per_iter': 1000, 'num_eval_trajectories': 10, 'ep_len': 200, 'log_string': 'reacher-cs285-v0_reacher_ablation', 'env_name': 'reacher-cs285-v0', 'hidden_size': 250, 'learning_rate': 0.001, 'num_layers': 2}
# ########################
# logging outputs to  C:\Users\user\Colab\Berkeley_DeepRL_Fall2023\hw4\cs285\scripts\../../data\problem4\reacher-cs285-v0_reacher_ablation
# ########################
# Using CPU.
#
#
# ...

# %% [markdown]
# Modify (or make copies of) the YAML file to ablate each of the hyperparameters. For each hyperparameter, do at least 1 run with it increased and 1 with it decreased from the default (so 7 runs total). Make sure to keep the other hyperparameters the same when studying the effect of one of them.

# %%
# set ensemble_size=1 in reacher_ablation.yaml
# %run cs285/scripts/run_hw4.py -cfg experiments/mpc/reacher_ablation.yaml \
    --dir_name problem4 --exp_name reacher_ablation_ensemblesize=1
# Out:
# Namespace(config_file='experiments/mpc/reacher_ablation.yaml', sac_config_file=None, eval_interval=5000, num_render_trajectories=0, seed=1, no_gpu=False, which_gpu=0, dir_name='problem4', exp_name='reacher_ablation_ensemblesize=1')
# {'exp_name': 'reacher_ablation_ensemblesize=1', 'ensemble_size': 1, 'mpc_horizon': 10, 'mpc_strategy': 'random', 'mpc_num_action_sequences': 1000, 'cem_num_iters': None, 'cem_num_elites': None, 'cem_alpha': None, 'initial_batch_size': 5000, 'batch_size': 800, 'train_batch_size': 512, 'num_iters': 15, 'replay_buffer_capacity': 1000000, 'num_agent_train_steps_per_iter': 1000, 'num_eval_trajectories': 10, 'ep_len': 200, 'log_string': 'reacher-cs285-v0_reacher_ablation_ensemblesize=1', 'env_name': 'reacher-cs285-v0', 'hidden_size': 250, 'learning_rate': 0.001, 'num_layers': 2}
# ########################
# logging outputs to  C:\Users\user\Colab\Berkeley_DeepRL_Fall2023\hw4\cs285\scripts\../../data\problem4\reacher-cs285-v0_reacher_ablation_ensemblesize=1
# ...

# %%
# set ensemble_size=5 in reacher_ablation.yaml
# %run cs285/scripts/run_hw4.py -cfg experiments/mpc/reacher_ablation.yaml \
    --dir_name problem4 --exp_name reacher_ablation_ensemblesize=5
# Out:
# Namespace(config_file='experiments/mpc/reacher_ablation.yaml', sac_config_file=None, eval_interval=5000, num_render_trajectories=0, seed=1, no_gpu=False, which_gpu=0, dir_name='problem4', exp_name='reacher_ablation_ensemblesize=5')
# {'exp_name': 'reacher_ablation_ensemblesize=5', 'ensemble_size': 5, 'mpc_horizon': 10, 'mpc_strategy': 'random', 'mpc_num_action_sequences': 1000, 'cem_num_iters': None, 'cem_num_elites': None, 'cem_alpha': None, 'initial_batch_size': 5000, 'batch_size': 800, 'train_batch_size': 512, 'num_iters': 15, 'replay_buffer_capacity': 1000000, 'num_agent_train_steps_per_iter': 1000, 'num_eval_trajectories': 10, 'ep_len': 200, 'log_string': 'reacher-cs285-v0_reacher_ablation_ensemblesize=5', 'env_name': 'reacher-cs285-v0', 'hidden_size': 250, 'learning_rate': 0.001, 'num_layers': 2}
# ########################
# logging outputs to  C:\Users\user\Colab\Berkeley_DeepRL_Fall2023\hw4\cs285\scripts\../../data\problem4\reacher-cs285-v0_reacher_ablation_ensemblesize=5
# ...

# %%
# set mpc_num_action_sequences=500 in reacher_ablation.yaml
# %run cs285/scripts/run_hw4.py -cfg experiments/mpc/reacher_ablation.yaml \
    --dir_name problem4 --exp_name reacher_ablation_numactseq=500
# Out:
# Namespace(config_file='experiments/mpc/reacher_ablation.yaml', sac_config_file=None, eval_interval=5000, num_render_trajectories=0, seed=1, no_gpu=False, which_gpu=0, dir_name='problem4', exp_name='reacher_ablation_numactseq=500')
# {'exp_name': 'reacher_ablation_numactseq=500', 'ensemble_size': 3, 'mpc_horizon': 10, 'mpc_strategy': 'random', 'mpc_num_action_sequences': 500, 'cem_num_iters': None, 'cem_num_elites': None, 'cem_alpha': None, 'initial_batch_size': 5000, 'batch_size': 800, 'train_batch_size': 512, 'num_iters': 15, 'replay_buffer_capacity': 1000000, 'num_agent_train_steps_per_iter': 1000, 'num_eval_trajectories': 10, 'ep_len': 200, 'log_string': 'reacher-cs285-v0_reacher_ablation_numactseq=500', 'env_name': 'reacher-cs285-v0', 'hidden_size': 250, 'learning_rate': 0.001, 'num_layers': 2}
# ########################
# logging outputs to  C:\Users\user\Colab\Berkeley_DeepRL_Fall2023\hw4\cs285\scripts\../../data\problem4\reacher-cs285-v0_reacher_ablation_numactseq=500
# ...

# %%
# set mpc_num_action_sequences=1500 in reacher_ablation.yaml
# %run cs285/scripts/run_hw4.py -cfg experiments/mpc/reacher_ablation.yaml \
    --dir_name problem4 --exp_name reacher_ablation_numactseq=1500
# Out:
# Namespace(config_file='experiments/mpc/reacher_ablation.yaml', sac_config_file=None, eval_interval=5000, num_render_trajectories=0, seed=1, no_gpu=False, which_gpu=0, dir_name='problem4', exp_name='reacher_ablation_numactseq=1500')
# {'exp_name': 'reacher_ablation_numactseq=1500', 'ensemble_size': 3, 'mpc_horizon': 10, 'mpc_strategy': 'random', 'mpc_num_action_sequences': 1500, 'cem_num_iters': None, 'cem_num_elites': None, 'cem_alpha': None, 'initial_batch_size': 5000, 'batch_size': 800, 'train_batch_size': 512, 'num_iters': 15, 'replay_buffer_capacity': 1000000, 'num_agent_train_steps_per_iter': 1000, 'num_eval_trajectories': 10, 'ep_len': 200, 'log_string': 'reacher-cs285-v0_reacher_ablation_numactseq=1500', 'env_name': 'reacher-cs285-v0', 'hidden_size': 250, 'learning_rate': 0.001, 'num_layers': 2}
# ########################
# logging outputs to  C:\Users\user\Colab\Berkeley_DeepRL_Fall2023\hw4\cs285\scripts\../../data\problem4\reacher-cs285-v0_reacher_ablation_numactseq=1500
# ...

# %%
# set mpc_horizon=5 in reacher_ablation.yaml
# %run cs285/scripts/run_hw4.py -cfg experiments/mpc/reacher_ablation.yaml \
    --dir_name problem4 --exp_name reacher_ablation_horizon=5
# Out:
# Namespace(config_file='experiments/mpc/reacher_ablation.yaml', sac_config_file=None, eval_interval=5000, num_render_trajectories=0, seed=1, no_gpu=False, which_gpu=0, dir_name='problem4', exp_name='reacher_ablation_horizon=5')
# {'exp_name': 'reacher_ablation_horizon=5', 'ensemble_size': 3, 'mpc_horizon': 5, 'mpc_strategy': 'random', 'mpc_num_action_sequences': 1000, 'cem_num_iters': None, 'cem_num_elites': None, 'cem_alpha': None, 'initial_batch_size': 5000, 'batch_size': 800, 'train_batch_size': 512, 'num_iters': 15, 'replay_buffer_capacity': 1000000, 'num_agent_train_steps_per_iter': 1000, 'num_eval_trajectories': 10, 'ep_len': 200, 'log_string': 'reacher-cs285-v0_reacher_ablation_horizon=5', 'env_name': 'reacher-cs285-v0', 'hidden_size': 250, 'learning_rate': 0.001, 'num_layers': 2}
# ########################
# logging outputs to  C:\Users\user\Colab\Berkeley_DeepRL_Fall2023\hw4\cs285\scripts\../../data\problem4\reacher-cs285-v0_reacher_ablation_horizon=5
# ...

# %%
# set mpc_horizon=15 in reacher_ablation.yaml
# %run cs285/scripts/run_hw4.py -cfg experiments/mpc/reacher_ablation.yaml \
    --dir_name problem4 --exp_name reacher_ablation_horizon=15
# Out:
# Namespace(config_file='experiments/mpc/reacher_ablation.yaml', sac_config_file=None, eval_interval=5000, num_render_trajectories=0, seed=1, no_gpu=False, which_gpu=0, dir_name='problem4', exp_name='reacher_ablation_horizon=15')
# {'exp_name': 'reacher_ablation_horizon=15', 'ensemble_size': 3, 'mpc_horizon': 15, 'mpc_strategy': 'random', 'mpc_num_action_sequences': 1000, 'cem_num_iters': None, 'cem_num_elites': None, 'cem_alpha': None, 'initial_batch_size': 5000, 'batch_size': 800, 'train_batch_size': 512, 'num_iters': 15, 'replay_buffer_capacity': 1000000, 'num_agent_train_steps_per_iter': 1000, 'num_eval_trajectories': 10, 'ep_len': 200, 'log_string': 'reacher-cs285-v0_reacher_ablation_horizon=15', 'env_name': 'reacher-cs285-v0', 'hidden_size': 250, 'learning_rate': 0.001, 'num_layers': 2}
# ########################
# logging outputs to  C:\Users\user\Colab\Berkeley_DeepRL_Fall2023\hw4\cs285\scripts\../../data\problem4\reacher-cs285-v0_reacher_ablation_horizon=15
# ...

# %% [markdown]
# <u>What to submit:</u>
#
# 2. Include the following plots (as well as captions that describe your observed trends) of the following:
#     * effect of ensemble size
#       Compare the results of `ensemble_size = 1, 3, 5`, larger ensemble_size works better, ensemble_size=5 works best here.
#     * effect of the number of candidate action sequences
#       Compare the results of `mpc_num_action_sequences = 500, 1000, 1500`, larger mpc_num_action_sequences works better, mpc_num_action_sequences=1500 works best here.
#     * effect of planning horizon
#       Compare the results of `mpc_horizon = 5, 10, 15`, **smaller** mpc_horizon works better, mpc_horizon=5 works best here.

# %%
# %load_ext tensorboard
# %tensorboard --logdir data/problem4

# %% [markdown]
# # Problem 5

# %% [markdown]
# <u>What will you implement:</u>
# You will compare the performance of your MBRL algorithm with action selecting performed by randomshooting (what you have done up to this point) and CEM.
#
# Because CEM can be much slower than random-shooting, we will only run MBRL for 5 iterations for this problem. We will try two hyperparameter settings for CEM and compare their performance to randomshooting.
# * You should expect rewards around 800 or higher when using CEM on the cheetah env.

# %%
# executing for about 2.3 hr (on localhost CPU, i5-12400)
# set cem_num_iters=4(default) in halfcheetah_cem.yaml
# %run cs285/scripts/run_hw4.py -cfg experiments/mpc/halfcheetah_cem.yaml \
    --dir_name problem5 --exp_name cheetah_cem_cemnumiters=4 -nvid 2
# Out:
# Namespace(config_file='experiments/mpc/halfcheetah_cem.yaml', sac_config_file=None, eval_interval=5000, num_render_trajectories=2, seed=1, no_gpu=False, which_gpu=0, dir_name='problem5', exp_name='cheetah_cem_cemnumiters=4')
# {'exp_name': 'cheetah_cem_cemnumiters=4', 'ensemble_size': 3, 'mpc_horizon': 15, 'mpc_strategy': 'cem', 'mpc_num_action_sequences': 1000, 'cem_num_iters': 4, 'cem_num_elites': 5, 'cem_alpha': 1, 'initial_batch_size': 5000, 'batch_size': 5000, 'train_batch_size': 512, 'num_iters': 5, 'replay_buffer_capacity': 1000000, 'num_agent_train_steps_per_iter': 1500, 'num_eval_trajectories': 10, 'ep_len': 500, 'log_string': 'cheetah-cs285-v0_cheetah_cem_cemnumiters=4', 'env_name': 'cheetah-cs285-v0', 'hidden_size': 250, 'learning_rate': 0.001, 'num_layers': 2}
# ########################
# logging outputs to  C:\Users\user\Colab\Berkeley_DeepRL_Fall2023\hw4\cs285\scripts\../../data\problem5\cheetah-cs285-v0_cheetah_cem_cemnumiters=4
# ########################
# Using CPU.
# ...

# %% [markdown]
# Try a cem_iterations value of both 2 and 4, and compare results.

# %%
# executing for about 1.2 hr (on localhost CPU, i5-12400)
# set cem_num_iters=2 in halfcheetah_cem.yaml
# %run cs285/scripts/run_hw4.py -cfg experiments/mpc/halfcheetah_cem.yaml \
    --dir_name problem5 --exp_name cheetah_cem_cemnumiters=2 -nvid 2
# Out:
# Namespace(config_file='experiments/mpc/halfcheetah_cem.yaml', sac_config_file=None, eval_interval=5000, num_render_trajectories=2, seed=1, no_gpu=False, which_gpu=0, dir_name='problem5', exp_name='cheetah_cem_cemnumiters=2')
# {'exp_name': 'cheetah_cem_cemnumiters=2', 'ensemble_size': 3, 'mpc_horizon': 15, 'mpc_strategy': 'cem', 'mpc_num_action_sequences': 1000, 'cem_num_iters': 2, 'cem_num_elites': 5, 'cem_alpha': 1, 'initial_batch_size': 5000, 'batch_size': 5000, 'train_batch_size': 512, 'num_iters': 5, 'replay_buffer_capacity': 1000000, 'num_agent_train_steps_per_iter': 1500, 'num_eval_trajectories': 10, 'ep_len': 500, 'log_string': 'cheetah-cs285-v0_cheetah_cem_cemnumiters=2', 'env_name': 'cheetah-cs285-v0', 'hidden_size': 250, 'learning_rate': 0.001, 'num_layers': 2}
# ########################
# logging outputs to  C:\Users\user\Colab\Berkeley_DeepRL_Fall2023\hw4\cs285\scripts\../../data\problem5\cheetah-cs285-v0_cheetah_cem_cemnumiters=2
# ########################
# Using CPU.
# ...

# %% [markdown]
# <u>What to submit:</u>
#
# 2. Include a plot comparing random shooting (from Problem 3) with CEM, as well as captions that describe how CEM affects results for different numbers of sampling iterations (2 vs. 4).
#    Compare the results of `random shooting` and `cem_num_iters = 2, 4`, cem works better, and cem_num_iters=4 works best here.

# %%
# %load_ext tensorboard
# %tensorboard --logdir data/problem5

# %% [markdown]
# # Problem 6

# %% [markdown]
# <u>What will you implement:</u>
# In this homework you will also be implementing a variant of [MBPO](https://arxiv.org/pdf/1906.08253). Another way of leveraging the learned model is through generating additional samples to train the policy and value functions. Since RL often requires many environment interaction samples, which can be costly, we can use our learned model to generate additional samples to improve sample complexity. In MBPO, we build on your SAC implementation from HW3 and use the learned model you implemented in the earlier questions for generating additional samples to train our SAC agent. We will try three settings:
# 1. Model-free SAC baseline: no additional rollouts from the learned model.
# 2. Dyna (technically “dyna-style” - the original Dyna algorithm is a little different): add single-step rollouts from the model to the replay buffer and incorporate additional gradient steps per real world step.
# 4. MBPO: add in 10-step rollouts from the model to the replay buffer and incorporate additional gradient steps per real world step.
#
# Edit experiments/sac/halfcheetah_clipq.yaml to change the MBPO rollout length. The model-free SAC baseline corresponds to a rollout length of 0, The Dyna-like algorithm corresponds to a rollout length of 1, and full MBPO corresponds to a rollout length of 10.
# * You should be able to reach returns around 700 or higher with full MBPO with a rollout length of 10.

# %%
# Model-free SAC baseline
# set mbpo_rollout_length=0(default) in halfcheetah_clipq.yaml
# %run cs285/scripts/run_hw4.py -cfg experiments/mpc/halfcheetah_mbpo.yaml \
    --sac_config_file experiments/sac/halfcheetah_clipq.yaml \
    --dir_name problem6 --exp_name cheetah_mbpo_rolloutlen=0 -nvid 2
# Out:
# Namespace(config_file='experiments/mpc/halfcheetah_mbpo.yaml', sac_config_file='experiments/sac/halfcheetah_clipq.yaml', eval_interval=5000, num_render_trajectories=2, seed=1, no_gpu=False, which_gpu=0, dir_name='problem6', exp_name='cheetah_mbpo_rolloutlen=0')
# {'exp_name': 'cheetah_mbpo_rolloutlen=0', 'ensemble_size': 3, 'mpc_horizon': 10, 'mpc_strategy': 'random', 'mpc_num_action_sequences': 1000, 'cem_num_iters': None, 'cem_num_elites': None, 'cem_alpha': None, 'initial_batch_size': 5000, 'batch_size': 5000, 'train_batch_size': 512, 'num_iters': 10, 'replay_buffer_capacity': 1000000, 'num_agent_train_steps_per_iter': 1500, 'num_eval_trajectories': 10, 'ep_len': 500, 'log_string': 'cheetah-cs285-v0_cheetah_mbpo_rolloutlen=0', 'env_name': 'cheetah-cs285-v0', 'hidden_size': 250, 'learning_rate': 0.001, 'num_layers': 2}
# ########################
# ...

# %%
# Dyna-like algorithm
# set mbpo_rollout_length=1 in halfcheetah_clipq.yaml
# %run cs285/scripts/run_hw4.py -cfg experiments/mpc/halfcheetah_mbpo.yaml \
    --sac_config_file experiments/sac/halfcheetah_clipq.yaml \
    --dir_name problem6 --exp_name cheetah_mbpo_rolloutlen=1 -nvid 2
# Out:
# Namespace(config_file='experiments/mpc/halfcheetah_mbpo.yaml', sac_config_file='experiments/sac/halfcheetah_clipq.yaml', eval_interval=5000, num_render_trajectories=2, seed=1, no_gpu=False, which_gpu=0, dir_name='problem6', exp_name='cheetah_mbpo_rolloutlen=1')
# {'exp_name': 'cheetah_mbpo_rolloutlen=1', 'ensemble_size': 3, 'mpc_horizon': 10, 'mpc_strategy': 'random', 'mpc_num_action_sequences': 1000, 'cem_num_iters': None, 'cem_num_elites': None, 'cem_alpha': None, 'initial_batch_size': 5000, 'batch_size': 5000, 'train_batch_size': 512, 'num_iters': 10, 'replay_buffer_capacity': 1000000, 'num_agent_train_steps_per_iter': 1500, 'num_eval_trajectories': 10, 'ep_len': 500, 'log_string': 'cheetah-cs285-v0_cheetah_mbpo_rolloutlen=1', 'env_name': 'cheetah-cs285-v0', 'hidden_size': 250, 'learning_rate': 0.001, 'num_layers': 2}
# ########################
# ...

# %%
# MBPO
# set mbpo_rollout_length=10 in halfcheetah_clipq.yaml
# %run cs285/scripts/run_hw4.py -cfg experiments/mpc/halfcheetah_mbpo.yaml \
    --sac_config_file experiments/sac/halfcheetah_clipq.yaml \
    --dir_name problem6 --exp_name cheetah_mbpo_rolloutlen=10 -nvid 2
# Out:
# Namespace(config_file='experiments/mpc/halfcheetah_mbpo.yaml', sac_config_file='experiments/sac/halfcheetah_clipq.yaml', eval_interval=5000, num_render_trajectories=2, seed=1, no_gpu=False, which_gpu=0, dir_name='problem6', exp_name='cheetah_mbpo_rolloutlen=10')
# {'exp_name': 'cheetah_mbpo_rolloutlen=10', 'ensemble_size': 3, 'mpc_horizon': 10, 'mpc_strategy': 'random', 'mpc_num_action_sequences': 1000, 'cem_num_iters': None, 'cem_num_elites': None, 'cem_alpha': None, 'initial_batch_size': 5000, 'batch_size': 5000, 'train_batch_size': 512, 'num_iters': 10, 'replay_buffer_capacity': 1000000, 'num_agent_train_steps_per_iter': 1500, 'num_eval_trajectories': 10, 'ep_len': 500, 'log_string': 'cheetah-cs285-v0_cheetah_mbpo_rolloutlen=10', 'env_name': 'cheetah-cs285-v0', 'hidden_size': 250, 'learning_rate': 0.001, 'num_layers': 2}
# ########################
# ...

# %% [markdown]
# <u>What to submit:</u>
#
# 2. Include a plot to show a comparison between the 3 runs, and explain any trends you see.
#    Compare the results of `mbpo_rollout_length = 0, 1, 10` (corresponding to Model-free SAC, Dyna-like and MBPO), MBPO works best here.

# %%
# %load_ext tensorboard
# %tensorboard --logdir data/problem6
